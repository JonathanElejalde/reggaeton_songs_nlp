# %%
# %cd /content/drive/My Drive/Colab Notebooks/regaetton_songs_nlp
# Out:
# /content/drive/My Drive/Colab Notebooks/regaetton_songs_nlp

# %%
normalized_eval_path = '/content/drive/MyDrive/Colab Notebooks/regaetton_songs_nlp/data/normalized_eval_lyrics.csv'
split_train_path = '/content/drive/MyDrive/Colab Notebooks/regaetton_songs_nlp/data/normalized_train_split.csv'
scores_path = '/content/drive/MyDrive/Colab Notebooks/regaetton_songs_nlp/data/scores.csv'
cbow_path = '/content/drive/MyDrive/Colab Notebooks/regaetton_songs_nlp/embeddings/cbow_model.bin'
skip_path = '/content/drive/MyDrive/Colab Notebooks/regaetton_songs_nlp/embeddings/skip_model.bin'

# %%
import numpy as np
import pandas as pd
import keras

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras import layers
from keras.models import Model, Sequential
from keras.initializers import Constant
from keras.metrics import Accuracy, Recall
from gensim.models import Word2Vec
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score

def add_score(df, model, parameters, accuracy, recall):
    row = {'model': model, 'parameters': parameters,
           'accuracy': accuracy, 'recall': recall}
    df = df.append(row, ignore_index=True)

    return df

# %%
train = pd.read_csv(split_train_path)
eval = pd.read_csv(normalized_eval_path)
scores = pd.read_csv(scores_path)
cbow_model = Word2Vec.load(cbow_path)
skip_model = Word2Vec.load(skip_path)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(train.lyrics.values, train.sexual_content.values, 
                                                      stratify=train.sexual_content.values, random_state=10,
                                                      test_size=0.15, shuffle=True)

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)
train_sequences = tokenizer.texts_to_sequences(X_train)
valid_sequences = tokenizer.texts_to_sequences(X_valid)
eval_sequences = tokenizer.texts_to_sequences(eval.lyrics.values)
word_index = tokenizer.word_index
print(f'{len(word_index)} unique tokens.')
# Out:
# 41013 unique tokens.

# %%
max_len_sequence = 1000

train_data = pad_sequences(train_sequences, maxlen=max_len_sequence)
valid_data = pad_sequences(valid_sequences, maxlen=max_len_sequence)
eval_data = pad_sequences(eval_sequences, maxlen=max_len_sequence)
train_labels = to_categorical(np.asarray(y_train))
valid_labels = to_categorical(np.asarray(y_valid))
eval_labels = to_categorical(np.asarray(eval.sexual_content.values))

# %%
emb_dim = 300
num_words = len(word_index) + 1 # plus 1 for unknown words

embedding_matrix = np.zeros((num_words, emb_dim))
for word, i in word_index.items():
    embedding_vector = cbow_model.wv[word]
    embedding_matrix[i] = embedding_vector
    
# load these pre-trained word embeddings into an Embedding layer
embedding_layer = layers.Embedding(num_words,
                            emb_dim,
                            embeddings_initializer=Constant(embedding_matrix),
                            input_length=max_len_sequence,
                            trainable=False)

# %% [markdown]
# # Train CNN model

# %%
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True,
)

# %%
model = Sequential([
    embedding_layer,
    layers.Conv1D(128, 5, activation='relu'),
    layers.MaxPooling1D(5),
    layers.Conv1D(128, 5, activation='relu'),
    layers.MaxPooling1D(5),
    layers.Conv1D(128, 5, activation='relu'),
    layers.GlobalAveragePooling1D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(2, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', Recall()])
model.fit(train_data, train_labels,
          batch_size=256,
          epochs=100, validation_data=(valid_data, valid_labels), 
          callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 19/19 [==============================] - 5s 184ms/step - loss: 0.6777 - accuracy: 0.5560 - recall_7: 0.5560 - val_loss: 0.5963 - val_accuracy: 0.6810 - val_recall_7: 0.6810
# Epoch 2/100
# 19/19 [==============================] - 3s 158ms/step - loss: 0.6275 - accuracy: 0.6552 - recall_7: 0.6552 - val_loss: 0.5756 - val_accuracy: 0.6965 - val_recall_7: 0.6965
# Epoch 3/100
# 19/19 [==============================] - 3s 158ms/step - loss: 0.6061 - accuracy: 0.6745 - recall_7: 0.6745 - val_loss: 0.5766 - val_accuracy: 0.6810 - val_recall_7: 0.6810
# Epoch 4/100
# 19/19 [==============================] - 3s 158ms/step - loss: 0.6040 - accuracy: 0.6761 - recall_7: 0.6761 - val_loss: 0.5517 - val_accuracy: 0.7109 - val_recall_7: 0.7109
# Epoch 5/100
# 19/19 [==============================] - 3s 157ms/step - loss: 0.5708 - accuracy: 0.7024 - recall_7: 0.7024 - val_loss: 0.5386 - val_accuracy: 0.7276 - val_recall_7: 0.7276
# Epoch 6/100
# 19/19 [==============================] - 3s 157ms/step - loss: 0.5621 - accuracy: 0.7176 - recall_7: 0.7176 - val_loss: 0.5371 - val_accuracy: 0.7145 - val_recall_7: 0.7145
# Epoch 7/100
# 19/19 [==============================] - 3s 159ms/step - loss: 0.5410 - accuracy: 0.7275 - recall_7: 0.7275 - val_loss: 0.5237 - val_accuracy: 0.7300 - val_recall_7: 0.7300
# Epoch 8/100
# 19/19 [==============================] - 3s 159ms/step - loss: 0.5213 - accuracy: 0.7523 - recall_7: 0.7523 - val_loss: 0.5242 - val_accuracy: 0.7348 - val_recall_7: 0.7348
# Epoch 9/100
# 19/19 [==============================] - 3s 158ms/step - loss: 0.4941 - accuracy: 0.7684 - recall_7: 0.7684 - val_loss: 0.5094 - val_accuracy: 0.7503 - val_recall_7: 0.7503
# Epoch 10/100
# 19/19 [==============================] - 3s 158ms/step - loss: 0.4452 - accuracy: 0.8032 - recall_7: 0.8032 - val_loss: 0.6129 - val_accuracy: 0.6822 - val_recall_7: 0.6822
# Epoch 11/100
# 19/19 [==============================] - 3s 159ms/step - loss: 0.4817 - accuracy: 0.7726 - recall_7: 0.7726 - val_loss: 0.5314 - val_accuracy: 0.7467 - val_recall_7: 0.7467
# Epoch 12/100
# 19/19 [==============================] - 3s 158ms/step - loss: 0.4245 - accuracy: 0.8166 - recall_7: 0.8166 - val_loss: 0.5680 - val_accuracy: 0.7360 - val_recall_7: 0.7360
# Epoch 13/100
# 19/19 [==============================] - 3s 157ms/step - loss: 0.2971 - accuracy: 0.8894 - recall_7: 0.8894 - val_loss: 0.5790 - val_accuracy: 0.7455 - val_recall_7: 0.7455
# Epoch 14/100
# 19/19 [==============================] - 3s 157ms/step - loss: 0.2191 - accuracy: 0.9265 - recall_7: 0.9265 - val_loss: 0.6069 - val_accuracy: 0.7431 - val_recall_7: 0.7431
# Epoch 15/100
# 19/19 [==============================] - 3s 158ms/step - loss: 0.1930 - accuracy: 0.9341 - recall_7: 0.9341 - val_loss: 0.6678 - val_accuracy: 0.7360 - val_recall_7: 0.7360
# Epoch 16/100
# 19/19 [==============================] - 3s 158ms/step - loss: 0.1440 - accuracy: 0.9557 - recall_7: 0.9557 - val_loss: 0.8524 - val_accuracy: 0.6703 - val_recall_7: 0.6703
# Epoch 17/100
# 19/19 [==============================] - 3s 158ms/step - loss: 0.2726 - accuracy: 0.8910 - recall_7: 0.8910 - val_loss: 0.6841 - val_accuracy: 0.7264 - val_recall_7: 0.7264
# Epoch 18/100
# 19/19 [==============================] - 3s 157ms/step - loss: 0.1028 - accuracy: 0.9728 - recall_7: 0.9728 - val_loss: 0.8114 - val_accuracy: 0.7395 - val_recall_7: 0.7395
# Epoch 19/100
# 19/19 [==============================] - 3s 158ms/step - loss: 0.0366 - accuracy: 0.9950 - recall_7: 0.9950 - val_loss: 0.9803 - val_accuracy: 0.7419 - val_recall_7: 0.7419

# %%
# Predict on hand-labeled data
cnn_loss, cnn_accuracy, cnn_recall = model.evaluate(eval_data, eval_labels)

print(cnn_accuracy)
print(cnn_recall)
# Out:
# 19/19 [==============================] - 0s 19ms/step - loss: 0.5147 - accuracy: 0.7483 - recall_7: 0.7483
# 0.7483333349227905
# 0.7483333349227905

# %%
scores = add_score(scores, 'CNN on lyrics embeddings (word2vec - cbow)', 
                   {'optimizer': 'adam', 'Conv + pooling': 3, 'filters-size': (128, 5), 'batch_size': 256}, cnn_accuracy, cnn_recall)
scores.to_csv(scores_path, index=False)

# %% [markdown]
# # Train an LSTM model

# %%
lstm_early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=3,
    restore_best_weights=True,
)

# %%
lstm = Sequential([
    embedding_layer,
    layers.SpatialDropout1D(0.3),
    layers.LSTM(100, dropout=0.2, recurrent_dropout=0.2),
    layers.Dense(1024, activation='relu'),
    layers.Dropout(0.8),
    layers.Dense(1024, activation='relu'),
    layers.Dropout(0.8),
    layers.Dense(2, activation='softmax'),
])

lstm.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy', Recall()])

lstm.fit(train_data, train_labels,
          batch_size=32,
          epochs=100,
          validation_data=(valid_data, valid_labels), 
          callbacks=[lstm_early_stopping])
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/100
# 149/149 [==============================] - 496s 3s/step - loss: 0.7137 - accuracy: 0.5282 - recall_9: 0.5282 - val_loss: 0.6586 - val_accuracy: 0.6189 - val_recall_9: 0.6189
# Epoch 2/100
# 149/149 [==============================] - 493s 3s/step - loss: 0.6947 - accuracy: 0.5692 - recall_9: 0.5692 - val_loss: 0.6483 - val_accuracy: 0.6404 - val_recall_9: 0.6404
# Epoch 3/100
# 149/149 [==============================] - 493s 3s/step - loss: 0.6703 - accuracy: 0.5997 - recall_9: 0.5997 - val_loss: 0.6519 - val_accuracy: 0.6165 - val_recall_9: 0.6165
# Epoch 4/100
# 149/149 [==============================] - 493s 3s/step - loss: 0.6570 - accuracy: 0.6125 - recall_9: 0.6125 - val_loss: 0.6283 - val_accuracy: 0.6918 - val_recall_9: 0.6918
# Epoch 5/100
# 149/149 [==============================] - 493s 3s/step - loss: 0.6252 - accuracy: 0.6568 - recall_9: 0.6568 - val_loss: 0.6151 - val_accuracy: 0.6428 - val_recall_9: 0.6428
# Epoch 6/100
# 149/149 [==============================] - 495s 3s/step - loss: 0.6166 - accuracy: 0.6622 - recall_9: 0.6622 - val_loss: 0.5509 - val_accuracy: 0.7264 - val_recall_9: 0.7264
# Epoch 7/100
# 149/149 [==============================] - 493s 3s/step - loss: 0.5944 - accuracy: 0.6875 - recall_9: 0.6875 - val_loss: 0.5861 - val_accuracy: 0.7073 - val_recall_9: 0.7073
# Epoch 8/100
# 149/149 [==============================] - 495s 3s/step - loss: 0.5872 - accuracy: 0.6955 - recall_9: 0.6955 - val_loss: 0.5821 - val_accuracy: 0.6930 - val_recall_9: 0.6930
# Epoch 9/100
# 149/149 [==============================] - 496s 3s/step - loss: 0.5912 - accuracy: 0.6943 - recall_9: 0.6943 - val_loss: 0.6143 - val_accuracy: 0.6691 - val_recall_9: 0.6691

# %%
lstm_loss, lstm_accuracy, lstm_recall = lstm.evaluate(eval_data, eval_labels)
print(lstm_accuracy)
print(lstm_recall)
# Out:
# 19/19 [==============================] - 5s 261ms/step - loss: 0.5259 - accuracy: 0.7400 - recall_9: 0.7400
# 0.7400000095367432
# 0.7400000095367432

# %%
scores = add_score(scores, 'LSTM on lyrics embeddings (word2vec - cbow)', 
                   {'optimizer': 'adam', 'LSTM layers - units': (1, 100), 'Dense layers - units': (2, 1024),
                    'Dropout rate after dense layers': 0.8, 'batch_size': 32}, lstm_accuracy, lstm_recall)
scores.to_csv(scores_path, index=False)

# %% [markdown]
# # GRU

# %%
gru = Sequential([
    embedding_layer,
    layers.SpatialDropout1D(0.3),
    layers.GRU(300, dropout=0.3, recurrent_dropout=0.3, return_sequences=True),
    layers.GRU(300, dropout=0.3, recurrent_dropout=0.3),
    layers.Dense(1024, activation='relu'),
    layers.Dropout(0.8),
    layers.Dense(1024, activation='relu'),
    layers.Dropout(0.8),
    layers.Dense(2, activation='softmax'),
])

gru.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy', Recall()])

gru.fit(train_data, train_labels,
          batch_size=128,
          epochs=100,
          validation_data=(valid_data, valid_labels), 
          callbacks=[lstm_early_stopping])
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/100
# 38/38 [==============================] - 246s 6s/step - loss: 0.7291 - accuracy: 0.5343 - recall_10: 0.5343 - val_loss: 0.7000 - val_accuracy: 0.5699 - val_recall_10: 0.5699
# Epoch 2/100
# 38/38 [==============================] - 240s 6s/step - loss: 0.7211 - accuracy: 0.5506 - recall_10: 0.5506 - val_loss: 0.6758 - val_accuracy: 0.5603 - val_recall_10: 0.5603
# Epoch 3/100
# 38/38 [==============================] - 240s 6s/step - loss: 0.7147 - accuracy: 0.5399 - recall_10: 0.5399 - val_loss: 0.6838 - val_accuracy: 0.5651 - val_recall_10: 0.5651
# Epoch 4/100
# 38/38 [==============================] - 241s 6s/step - loss: 0.7216 - accuracy: 0.5231 - recall_10: 0.5231 - val_loss: 0.6788 - val_accuracy: 0.5412 - val_recall_10: 0.5412
# Epoch 5/100
# 38/38 [==============================] - 242s 6s/step - loss: 0.7096 - accuracy: 0.5335 - recall_10: 0.5335 - val_loss: 0.6712 - val_accuracy: 0.5830 - val_recall_10: 0.5830
# Epoch 6/100
# 38/38 [==============================] - 245s 6s/step - loss: 0.6948 - accuracy: 0.5522 - recall_10: 0.5522 - val_loss: 0.6556 - val_accuracy: 0.6260 - val_recall_10: 0.6260
# Epoch 7/100
# 38/38 [==============================] - 247s 7s/step - loss: 0.6871 - accuracy: 0.5581 - recall_10: 0.5581 - val_loss: 0.6568 - val_accuracy: 0.6440 - val_recall_10: 0.6428
# Epoch 8/100
# 38/38 [==============================] - 248s 7s/step - loss: 0.6856 - accuracy: 0.5650 - recall_10: 0.5650 - val_loss: 0.6641 - val_accuracy: 0.5890 - val_recall_10: 0.5890
# Epoch 9/100
# 38/38 [==============================] - 248s 7s/step - loss: 0.6849 - accuracy: 0.5762 - recall_10: 0.5762 - val_loss: 0.6528 - val_accuracy: 0.6464 - val_recall_10: 0.6464
# Epoch 10/100
# 38/38 [==============================] - 244s 6s/step - loss: 0.6694 - accuracy: 0.5859 - recall_10: 0.5859 - val_loss: 0.6298 - val_accuracy: 0.6655 - val_recall_10: 0.6655
# Epoch 11/100
# 38/38 [==============================] - 245s 6s/step - loss: 0.6522 - accuracy: 0.6200 - recall_10: 0.6200 - val_loss: 0.6073 - val_accuracy: 0.6691 - val_recall_10: 0.6691
# Epoch 12/100
# 38/38 [==============================] - 242s 6s/step - loss: 0.6590 - accuracy: 0.6359 - recall_10: 0.6359 - val_loss: 0.5971 - val_accuracy: 0.6965 - val_recall_10: 0.6965
# Epoch 13/100
# 38/38 [==============================] - 241s 6s/step - loss: 0.6242 - accuracy: 0.6532 - recall_10: 0.6532 - val_loss: 0.5782 - val_accuracy: 0.6941 - val_recall_10: 0.6941
# Epoch 14/100
# 38/38 [==============================] - 248s 7s/step - loss: 0.6064 - accuracy: 0.6846 - recall_10: 0.6846 - val_loss: 0.5565 - val_accuracy: 0.7109 - val_recall_10: 0.7109
# Epoch 15/100
# 38/38 [==============================] - 244s 6s/step - loss: 0.6001 - accuracy: 0.6865 - recall_10: 0.6865 - val_loss: 0.5557 - val_accuracy: 0.7276 - val_recall_10: 0.7276
# Epoch 16/100
# 38/38 [==============================] - 243s 6s/step - loss: 0.5859 - accuracy: 0.6952 - recall_10: 0.6952 - val_loss: 0.5496 - val_accuracy: 0.7431 - val_recall_10: 0.7431
# Epoch 17/100
# 38/38 [==============================] - 242s 6s/step - loss: 0.5808 - accuracy: 0.7082 - recall_10: 0.7082 - val_loss: 0.5446 - val_accuracy: 0.7264 - val_recall_10: 0.7264
# Epoch 18/100
# 38/38 [==============================] - 240s 6s/step - loss: 0.5678 - accuracy: 0.7184 - recall_10: 0.7184 - val_loss: 0.5632 - val_accuracy: 0.6846 - val_recall_10: 0.6846
# Epoch 19/100
# 38/38 [==============================] - 242s 6s/step - loss: 0.5748 - accuracy: 0.7014 - recall_10: 0.7014 - val_loss: 0.5656 - val_accuracy: 0.7133 - val_recall_10: 0.7133
# Epoch 20/100
# 38/38 [==============================] - 241s 6s/step - loss: 0.5636 - accuracy: 0.7154 - recall_10: 0.7154 - val_loss: 0.5333 - val_accuracy: 0.7360 - val_recall_10: 0.7360
# Epoch 21/100
# 38/38 [==============================] - 242s 6s/step - loss: 0.5543 - accuracy: 0.7305 - recall_10: 0.7305 - val_loss: 0.5198 - val_accuracy: 0.7419 - val_recall_10: 0.7419
# Epoch 22/100
# 38/38 [==============================] - 244s 6s/step - loss: 0.5515 - accuracy: 0.7190 - recall_10: 0.7190 - val_loss: 0.5793 - val_accuracy: 0.6977 - val_recall_10: 0.6977
# Epoch 23/100
# 38/38 [==============================] - 247s 7s/step - loss: 0.5871 - accuracy: 0.7015 - recall_10: 0.7015 - val_loss: 0.6110 - val_accuracy: 0.6535 - val_recall_10: 0.6535
# Epoch 24/100
# 38/38 [==============================] - 248s 7s/step - loss: 0.5906 - accuracy: 0.6959 - recall_10: 0.6959 - val_loss: 0.5266 - val_accuracy: 0.7372 - val_recall_10: 0.7372

# %%
lstm_loss, gru_accuracy, gru_recall = gru.evaluate(eval_data, eval_labels)
print(lstm_accuracy)
print(lstm_recall)
# Out:
# 19/19 [==============================] - 11s 592ms/step - loss: 0.4983 - accuracy: 0.7417 - recall_10: 0.7417
# 0.7400000095367432
# 0.7400000095367432

# %%
scores = add_score(scores, 'GRU on lyrics embeddings (word2vec - cbow)', 
                   {'optimizer': 'adam', 'GRU layers - units': (2, 300), 'Dense layers - units': (2, 1024),
                    'Dropout rate after dense layers': 0.8, 'batch_size': 128}, gru_accuracy, gru_recall)
scores.to_csv(scores_path, index=False)

# %%
scores.head(50)
# Out:
#                                            model  ...    recall
# 0                      logistic regression - BoW  ...  0.685714
# 1                              naive bayes - BoW  ...  0.743243
# 2           logistic regression - Bag of n-grams  ...  0.721311
# 3                    naive bayes - Bag of ngrams  ...  0.645777
# 4   logistic regression - Bag of n-grams - tfidf  ...  0.748175
# 5                    naive bayes - Bag of ngrams  ...  0.744409
# 6            naive bayes - Bag of ngrams - tfidf  ...  0.744409
# 7                                            svm  ...  0.758755
# 8                     Gradient Boosting on Tfidf  ...  0.666667
# 9          Gradient Boosting on count vectorizer  ...  0.681159
# 10                  Gradient Boosting on 120 svd  ...  0.688356
# 11           Gradient Boosting on 120 svd scaled  ...  0.732075
# 12                    Gradient Boosting on Tfidf  ...  0.762411
# 13                     Gradient Boosting on cbow  ...  0.762411
# 14                   Logistic regression on cbow  ...  0.761092
# 15               Logistic regression on skipgram  ...  0.690789
# 16    CNN on lyrics embeddings (word2vec - cbow)  ...  0.748333
# 17   LSTM on lyrics embeddings (word2vec - cbow)  ...  0.740000
# 18    GRU on lyrics embeddings (word2vec - cbow)  ...  0.741667
#
# [19 rows x 4 columns]

# %% [markdown]
# # To do's
#
# - try limiting the amount of words to the most frequent to reduce noisy misspelled words.
